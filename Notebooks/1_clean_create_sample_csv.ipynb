# %% [markdown]
# # AI Tools Dataset
#
#
# ## Data Fields
#
# - AI Tool Name: The name of the AI tool or software.
# - Description: A brief description of the tool's features and capabilities.
# - Free/Paid/Other: Indicates whether the tool is available for free, has a paid subscription model, or falls under another pricing category.
# - Useable For: Describes the primary use cases or applications for which the AI tool is suitable.
# - Charges: Specifies the cost or pricing structure associated with the tool (if applicable).
# - Review: User-generated reviews and ratings to provide insights into the tool's performance and user satisfaction.
# - Tool Link: URL or link to access the AI tool's official website or download page.
# - Major Category: Categorizes the AI tools into broader domains or categories, such as natural language processing (NLP), computer vision, data analytics, and more.

# %%
# %pip install missingno
import numpy as np
import pandas as pd
#pd.options.display.max_rows = None
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import missingno as msno
import networkx as nx
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
# %matplotlib inline
# %pip install tiktoken
import tiktoken
# Out:
# Requirement already satisfied: missingno in /Users/paksivatkinavaleria/anaconda3/lib/python3.11/site-packages (0.5.2)
# Requirement already satisfied: numpy in /Users/paksivatkinavaleria/anaconda3/lib/python3.11/site-packages (from missingno) (1.26.2)
# Requirement already satisfied: matplotlib in /Users/paksivatkinavaleria/anaconda3/lib/python3.11/site-packages (from missingno) (3.7.1)
# Requirement already satisfied: scipy in /Users/paksivatkinavaleria/anaconda3/lib/python3.11/site-packages (from missingno) (1.10.1)
# Requirement already satisfied: seaborn in /Users/paksivatkinavaleria/anaconda3/lib/python3.11/site-packages (from missingno) (0.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/paksivatkinavaleria/anaconda3/lib/python3.11/site-packages (from matplotlib->missingno) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/paksivatkinavaleria/anaconda3/lib/python3.11/site-packages (from matplotlib->missingno) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/paksivatkinavaleria/anaconda3/lib/python3.11/site-packages (from matplotlib->missingno) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/paksivatkinavaleria/anaconda3/lib/python3.11/site-packages (from matplotlib->missingno) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/paksivatkinavaleria/anaconda3/lib/python3.11/site-packages (from matplotlib->missingno) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/paksivatkinavaleria/anaconda3/lib/python3.11/site-packages (from matplotlib->missingno) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/paksivatkinavaleria/anaconda3/lib/python3.11/site-packages (from matplotlib->missingno) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/paksivatkinavaleria/anaconda3/lib/python3.11/site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pandas>=1.2 in /Users/paksivatkinavaleria/anaconda3/lib/python3.11/site-packages (from seaborn->missingno) (2.1.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/paksivatkinavaleria/anaconda3/lib/python3.11/site-packages (from pandas>=1.2->seaborn->missingno) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/paksivatkinavaleria/anaconda3/lib/python3.11/site-packages (from pandas>=1.2->seaborn->missingno) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/paksivatkinavaleria/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tiktoken in /Users/paksivatkinavaleria/anaconda3/lib/python3.11/site-packages (0.7.0)
# Requirement already satisfied: regex>=2022.1.18 in /Users/paksivatkinavaleria/anaconda3/lib/python3.11/site-packages (from tiktoken) (2024.5.15)
# Requirement already satisfied: requests>=2.26.0 in /Users/paksivatkinavaleria/anaconda3/lib/python3.11/site-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/paksivatkinavaleria/anaconda3/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/paksivatkinavaleria/anaconda3/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/paksivatkinavaleria/anaconda3/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/paksivatkinavaleria/anaconda3/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_csv('./all_ai_tool 3.csv')
df
# Out:
#         AI Tool Name                                        Description  \
# 0             Farm3D  Learning Articulated 3D Animals by Distilling ...
# 1      Mailbutler Ai  AI-powered Smart Assistant for Outlook, Gmail ...
# 2          Maverick      Send customers personalized videos at scale.
# 3               0Xai      Stable Diffusion Prompt And Images Generator
# 4              10Web  AI-powered WordPress platform for automated we...
# ...              ...                                                ...
# 4964         Zoom Iq  Capture meaningful and actionable insights fro...
# 4965    Zoomscape Ai  ZoomScape AI is an AI-powered tool that enable...
# 4966         Zust Qr  Enables users to craft artistic QR codes by in...
# 4967            Zuva          Contract analysis and insight generation.
# 4968            Zyng  Generation of promotional images without desig...
#
#           Free/Paid/Other                          Useable For    Charges  \
# 0                    Free                / experiments    / 3D        NaN
# 1                Freemium                    / email assistant  $ 4.95/mo
# 2                    Paid      / e-commerce    / audio editing   $ 100/mo
# 3                    Free       / image generator    / prompts        NaN
# 4                Freemium                   / low-code/no-code        NaN
# ...                   ...                                  ...        ...
# 4964  Contact for Pricing    / summarizer    / email assistant        NaN
# 4965           Free Trial                      / presentations        $5
# 4966                 Free                    / image generator        NaN
# 4967           Free Trial                    / legal assistant    $ 50/mo
# 4968                 Free    / e-commerce    / image generator        NaN
#
#      Review                                          Tool Link Major Category
# 0       NaN  https://farm3d.github.io/?utm_source=futureped...          other
# 1         1  https://www.mailbutler.io/smart-assistant/?utm...           text
# 2       NaN  https://www.trymaverick.com/?utm_source=future...          audio
# 3       NaN  https://0xai.quest?utm_source=futurepedia&utm_...          image
# 4       NaN  https://10web.io/?utm_source=futurepedia&utm_m...           code
# ...     ...                                                ...            ...
# 4964      2  https://blog.zoom.us/zoom-iq-smart-companion/?...           text
# 4965    NaN  https://zoomscape.ai/?utm_source=futurepedia&u...       business
# 4966    NaN  https://qr.zust.ai/?utm_source=futurepedia&utm...          image
# 4967      1  https://zuva.ai/widget/try-it/?utm_source=futu...       business
# 4968    NaN  https://www.zyngai.com/?utm_source=futurepedia...          image
#
# [4969 rows x 8 columns]

# %%
rows,cols = df.shape
print("Number of rows: ", rows)
print("Number of columns: ", cols)
# Out:
# Number of rows:  4969
# Number of columns:  8

# %%
df.describe()
# Out:
#        AI Tool Name                             Description Free/Paid/Other  \
# count          4969                                    4969            4969
# unique         4969                                    4965              19
# top          Farm3D  Understand any data instantly using AI            Free
# freq              1                                       2            1704
#
#              Useable For  Charges Review  \
# count               4969     2534   1462
# unique               526      557     17
# top       / productivity  $ 10/mo      1
# freq                 247       99    942
#
#                                                 Tool Link Major Category
# count                                                4969           4969
# unique                                               4959              8
# top     https://www.trymaverick.com/?utm_source=future...       business
# freq                                                    2           1202

# %% [markdown]
# Create column 'Id'

# %%
# Crear una columna 'Id' que sea igual al índice
df['Id'] = df.index

# %% [markdown]
# Reorder columns

# %%
# Reordenar las columnas para que 'Id' sea la primera
df = df[['Id', 'AI Tool Name', 'Tool Link','Free/Paid/Other','Review', 'Major Category','Useable For', 'Description','Charges']]
df.head()
# Out:
#    Id    AI Tool Name                                          Tool Link  \
# 0   0          Farm3D  https://farm3d.github.io/?utm_source=futureped...
# 1   1   Mailbutler Ai  https://www.mailbutler.io/smart-assistant/?utm...
# 2   2       Maverick   https://www.trymaverick.com/?utm_source=future...
# 3   3            0Xai  https://0xai.quest?utm_source=futurepedia&utm_...
# 4   4           10Web  https://10web.io/?utm_source=futurepedia&utm_m...
#
#   Free/Paid/Other Review Major Category                        Useable For  \
# 0            Free    NaN          other              / experiments    / 3D
# 1        Freemium      1           text                  / email assistant
# 2            Paid    NaN          audio    / e-commerce    / audio editing
# 3            Free    NaN          image     / image generator    / prompts
# 4        Freemium    NaN           code                 / low-code/no-code
#
#                                          Description    Charges
# 0  Learning Articulated 3D Animals by Distilling ...        NaN
# 1  AI-powered Smart Assistant for Outlook, Gmail ...  $ 4.95/mo
# 2     Send customers personalized videos at scale.     $ 100/mo
# 3      Stable Diffusion Prompt And Images Generator         NaN
# 4  AI-powered WordPress platform for automated we...        NaN

# %% [markdown]
# Work with NaN values

# %%
df.isnull().sum()
# Out:
# Id                    0
# AI Tool Name          0
# Tool Link             0
# Free/Paid/Other       0
# Review             3507
# Major Category        0
# Useable For           0
# Description           0
# Charges            2435
# dtype: int64

# %%
df.fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# Id                 0
# AI Tool Name       0
# Tool Link          0
# Free/Paid/Other    0
# Review             0
# Major Category     0
# Useable For        0
# Description        0
# Charges            0
# dtype: int64

# %%
df
# Out:
#         Id    AI Tool Name                                          Tool Link  \
# 0        0          Farm3D  https://farm3d.github.io/?utm_source=futureped...
# 1        1   Mailbutler Ai  https://www.mailbutler.io/smart-assistant/?utm...
# 2        2       Maverick   https://www.trymaverick.com/?utm_source=future...
# 3        3            0Xai  https://0xai.quest?utm_source=futurepedia&utm_...
# 4        4           10Web  https://10web.io/?utm_source=futurepedia&utm_m...
# ...    ...             ...                                                ...
# 4964  4964         Zoom Iq  https://blog.zoom.us/zoom-iq-smart-companion/?...
# 4965  4965    Zoomscape Ai  https://zoomscape.ai/?utm_source=futurepedia&u...
# 4966  4966         Zust Qr  https://qr.zust.ai/?utm_source=futurepedia&utm...
# 4967  4967            Zuva  https://zuva.ai/widget/try-it/?utm_source=futu...
# 4968  4968            Zyng  https://www.zyngai.com/?utm_source=futurepedia...
#
#           Free/Paid/Other Review Major Category  \
# 0                    Free      0          other
# 1                Freemium      1           text
# 2                    Paid      0          audio
# 3                    Free      0          image
# 4                Freemium      0           code
# ...                   ...    ...            ...
# 4964  Contact for Pricing      2           text
# 4965           Free Trial      0       business
# 4966                 Free      0          image
# 4967           Free Trial      1       business
# 4968                 Free      0          image
#
#                               Useable For  \
# 0                   / experiments    / 3D
# 1                       / email assistant
# 2         / e-commerce    / audio editing
# 3          / image generator    / prompts
# 4                      / low-code/no-code
# ...                                   ...
# 4964    / summarizer    / email assistant
# 4965                      / presentations
# 4966                    / image generator
# 4967                    / legal assistant
# 4968    / e-commerce    / image generator
#
#                                             Description    Charges
# 0     Learning Articulated 3D Animals by Distilling ...          0
# 1     AI-powered Smart Assistant for Outlook, Gmail ...  $ 4.95/mo
# 2        Send customers personalized videos at scale.     $ 100/mo
# 3         Stable Diffusion Prompt And Images Generator           0
# 4     AI-powered WordPress platform for automated we...          0
# ...                                                 ...        ...
# 4964  Capture meaningful and actionable insights fro...          0
# 4965  ZoomScape AI is an AI-powered tool that enable...        $5
# 4966  Enables users to craft artistic QR codes by in...          0
# 4967          Contract analysis and insight generation.    $ 50/mo
# 4968  Generation of promotional images without desig...          0
#
# [4969 rows x 9 columns]

# %% [markdown]
# Recategorize values in column 'Free/Paid/Other'

# %%
df['Free/Paid/Other'].unique()
'''
Free - Free, FreeDeals, FreeFremium, Freemium | Free, Free | Freemium | Paid, Free | Paid, 
Freemium - Freemium, Freemium | Free-Trial, Free-Trial | Freemium, Freemium | Deals, Freemium |Contact for Pricing
Paid - Paid, Contact for pricing, Free Trial, Free-Trial | Deals, Free-Trial | Paid,  Paid |Free-Trial, Paid | Deals, Deals

'''
# Out:
# '\nFree - Free, FreeDeals, FreeFremium, Freemium | Free, Free | Freemium | Paid, Free | Paid, \nFreemium - Freemium, Freemium | Free-Trial, Free-Trial | Freemium, Freemium | Deals, Freemium |Contact for Pricing\nPaid - Paid, Contact for pricing, Free Trial, Free-Trial | Deals, Free-Trial | Paid,  Paid |Free-Trial, Paid | Deals, Deals\n\n'

# %%
# Diccionario de mapeo
mapeo_categorias = {
    'Free': 'Free',
    'FreeDeals': 'Free',
    'FreeFreemium': 'Free',
    'Freemium | Free': 'Free',
    'Free | Freemium | Paid': 'Free',
    'Free | Paid': 'Free',
    'Freemium': 'Freemium',
    'Freemium | Free-Trial': 'Freemium',
    'Free-Trial | Freemium': 'Freemium',
    'Freemium | Deals': 'Freemium',
    'Freemium |Contact for Pricing': 'Freemium',
    'Paid': 'Paid',
    'Contact for Pricing': 'Paid',
    'Free Trial': 'Paid',
    'Free-Trial | Deals': 'Paid',
    'Free-Trial | Paid': 'Paid',
    'Paid |Free-Trial': 'Paid',
    'Paid | Deals': 'Paid',
    'Deals': 'Paid'
}

# %%
# Recategorizar los valores en la columna 'Plan'
df['Free/Paid/Other'] = df['Free/Paid/Other'].replace(mapeo_categorias)

# Mostrar el DataFrame después de recategorizar
print("\nDataFrame después de recategorizar:")
df
# Out:
# DataFrame después de recategorizar:
#         Id    AI Tool Name                                          Tool Link  \
# 0        0          Farm3D  https://farm3d.github.io/?utm_source=futureped...
# 1        1   Mailbutler Ai  https://www.mailbutler.io/smart-assistant/?utm...
# 2        2       Maverick   https://www.trymaverick.com/?utm_source=future...
# 3        3            0Xai  https://0xai.quest?utm_source=futurepedia&utm_...
# 4        4           10Web  https://10web.io/?utm_source=futurepedia&utm_m...
# ...    ...             ...                                                ...
# 4964  4964         Zoom Iq  https://blog.zoom.us/zoom-iq-smart-companion/?...
# 4965  4965    Zoomscape Ai  https://zoomscape.ai/?utm_source=futurepedia&u...
# 4966  4966         Zust Qr  https://qr.zust.ai/?utm_source=futurepedia&utm...
# 4967  4967            Zuva  https://zuva.ai/widget/try-it/?utm_source=futu...
# 4968  4968            Zyng  https://www.zyngai.com/?utm_source=futurepedia...
#
#      Free/Paid/Other Review Major Category  \
# 0               Free      0          other
# 1           Freemium      1           text
# 2               Paid      0          audio
# 3               Free      0          image
# 4           Freemium      0           code
# ...              ...    ...            ...
# 4964            Paid      2           text
# 4965            Paid      0       business
# 4966            Free      0          image
# 4967            Paid      1       business
# 4968            Free      0          image
#
#                               Useable For  \
# 0                   / experiments    / 3D
# 1                       / email assistant
# 2         / e-commerce    / audio editing
# 3          / image generator    / prompts
# 4                      / low-code/no-code
# ...                                   ...
# 4964    / summarizer    / email assistant
# 4965                      / presentations
# 4966                    / image generator
# 4967                    / legal assistant
# 4968    / e-commerce    / image generator
#
#                                             Description    Charges
# 0     Learning Articulated 3D Animals by Distilling ...          0
# 1     AI-powered Smart Assistant for Outlook, Gmail ...  $ 4.95/mo
# 2        Send customers personalized videos at scale.     $ 100/mo
# 3         Stable Diffusion Prompt And Images Generator           0
# 4     AI-powered WordPress platform for automated we...          0
# ...                                                 ...        ...
# 4964  Capture meaningful and actionable insights fro...          0
# 4965  ZoomScape AI is an AI-powered tool that enable...        $5
# 4966  Enables users to craft artistic QR codes by in...          0
# 4967          Contract analysis and insight generation.    $ 50/mo
# 4968  Generation of promotional images without desig...          0
#
# [4969 rows x 9 columns]

# %%
df['Free/Paid/Other'].unique()
# Out:
# array(['Free', 'Freemium', 'Paid'], dtype=object)

# %%
df.rename(columns={'Free/Paid/Other': 'Free/Paid'}, inplace=True)

# %%
df.head()
# Out:
#    Id    AI Tool Name                                          Tool Link  \
# 0   0          Farm3D  https://farm3d.github.io/?utm_source=futureped...
# 1   1   Mailbutler Ai  https://www.mailbutler.io/smart-assistant/?utm...
# 2   2       Maverick   https://www.trymaverick.com/?utm_source=future...
# 3   3            0Xai  https://0xai.quest?utm_source=futurepedia&utm_...
# 4   4           10Web  https://10web.io/?utm_source=futurepedia&utm_m...
#
#   Free/Paid Review Major Category                        Useable For  \
# 0      Free      0          other              / experiments    / 3D
# 1  Freemium      1           text                  / email assistant
# 2      Paid      0          audio    / e-commerce    / audio editing
# 3      Free      0          image     / image generator    / prompts
# 4  Freemium      0           code                 / low-code/no-code
#
#                                          Description    Charges
# 0  Learning Articulated 3D Animals by Distilling ...          0
# 1  AI-powered Smart Assistant for Outlook, Gmail ...  $ 4.95/mo
# 2     Send customers personalized videos at scale.     $ 100/mo
# 3      Stable Diffusion Prompt And Images Generator           0
# 4  AI-powered WordPress platform for automated we...          0

# %%
# Separar los valores y colocarlos en una lista
df['Useable For'] = df['Useable For'].str.split('/').apply(lambda x: [item.strip() for item in x if item.strip()])

# Mostrar el DataFrame después de separar y convertir en lista
print("\nDataFrame después de separar y convertir en lista:")
print(df)
# Out:
# DataFrame después de separar y convertir en lista:
#         Id    AI Tool Name                                          Tool Link  \
# 0        0          Farm3D  https://farm3d.github.io/?utm_source=futureped...
# 1        1   Mailbutler Ai  https://www.mailbutler.io/smart-assistant/?utm...
# 2        2       Maverick   https://www.trymaverick.com/?utm_source=future...
# 3        3            0Xai  https://0xai.quest?utm_source=futurepedia&utm_...
# 4        4           10Web  https://10web.io/?utm_source=futurepedia&utm_m...
# ...    ...             ...                                                ...
# 4964  4964         Zoom Iq  https://blog.zoom.us/zoom-iq-smart-companion/?...
# 4965  4965    Zoomscape Ai  https://zoomscape.ai/?utm_source=futurepedia&u...
# 4966  4966         Zust Qr  https://qr.zust.ai/?utm_source=futurepedia&utm...
# 4967  4967            Zuva  https://zuva.ai/widget/try-it/?utm_source=futu...
# 4968  4968            Zyng  https://www.zyngai.com/?utm_source=futurepedia...
#
#      Free/Paid Review Major Category                    Useable For  \
# 0         Free      0          other              [experiments, 3D]
# 1     Freemium      1           text              [email assistant]
# 2         Paid      0          audio    [e-commerce, audio editing]
# 3         Free      0          image     [image generator, prompts]
# 4     Freemium      0           code            [low-code, no-code]
# ...        ...    ...            ...                            ...
# 4964      Paid      2           text  [summarizer, email assistant]
# 4965      Paid      0       business                [presentations]
# 4966      Free      0          image              [image generator]
# 4967      Paid      1       business              [legal assistant]
# 4968      Free      0          image  [e-commerce, image generator]
#
#                                             Description    Charges
# 0     Learning Articulated 3D Animals by Distilling ...          0
# 1     AI-powered Smart Assistant for Outlook, Gmail ...  $ 4.95/mo
# 2        Send customers personalized videos at scale.     $ 100/mo
# 3         Stable Diffusion Prompt And Images Generator           0
# 4     AI-powered WordPress platform for automated we...          0
# ...                                                 ...        ...
# 4964  Capture meaningful and actionable insights fro...          0
# 4965  ZoomScape AI is an AI-powered tool that enable...        $5
# 4966  Enables users to craft artistic QR codes by in...          0
# 4967          Contract analysis and insight generation.    $ 50/mo
# 4968  Generation of promotional images without desig...          0
#
# [4969 rows x 9 columns]

# %%
df['Useable For']
# Out:
# 0                   [experiments, 3D]
# 1                   [email assistant]
# 2         [e-commerce, audio editing]
# 3          [image generator, prompts]
# 4                 [low-code, no-code]
#                     ...
# 4964    [summarizer, email assistant]
# 4965                  [presentations]
# 4966                [image generator]
# 4967                [legal assistant]
# 4968    [e-commerce, image generator]
# Name: Useable For, Length: 4969, dtype: object

# %%
df
# Out:
#         Id    AI Tool Name                                          Tool Link  \
# 0        0          Farm3D  https://farm3d.github.io/?utm_source=futureped...
# 1        1   Mailbutler Ai  https://www.mailbutler.io/smart-assistant/?utm...
# 2        2       Maverick   https://www.trymaverick.com/?utm_source=future...
# 3        3            0Xai  https://0xai.quest?utm_source=futurepedia&utm_...
# 4        4           10Web  https://10web.io/?utm_source=futurepedia&utm_m...
# ...    ...             ...                                                ...
# 4964  4964         Zoom Iq  https://blog.zoom.us/zoom-iq-smart-companion/?...
# 4965  4965    Zoomscape Ai  https://zoomscape.ai/?utm_source=futurepedia&u...
# 4966  4966         Zust Qr  https://qr.zust.ai/?utm_source=futurepedia&utm...
# 4967  4967            Zuva  https://zuva.ai/widget/try-it/?utm_source=futu...
# 4968  4968            Zyng  https://www.zyngai.com/?utm_source=futurepedia...
#
#      Free/Paid Review Major Category                    Useable For  \
# 0         Free      0          other              [experiments, 3D]
# 1     Freemium      1           text              [email assistant]
# 2         Paid      0          audio    [e-commerce, audio editing]
# 3         Free      0          image     [image generator, prompts]
# 4     Freemium      0           code            [low-code, no-code]
# ...        ...    ...            ...                            ...
# 4964      Paid      2           text  [summarizer, email assistant]
# 4965      Paid      0       business                [presentations]
# 4966      Free      0          image              [image generator]
# 4967      Paid      1       business              [legal assistant]
# 4968      Free      0          image  [e-commerce, image generator]
#
#                                             Description    Charges
# 0     Learning Articulated 3D Animals by Distilling ...          0
# 1     AI-powered Smart Assistant for Outlook, Gmail ...  $ 4.95/mo
# 2        Send customers personalized videos at scale.     $ 100/mo
# 3         Stable Diffusion Prompt And Images Generator           0
# 4     AI-powered WordPress platform for automated we...          0
# ...                                                 ...        ...
# 4964  Capture meaningful and actionable insights fro...          0
# 4965  ZoomScape AI is an AI-powered tool that enable...        $5
# 4966  Enables users to craft artistic QR codes by in...          0
# 4967          Contract analysis and insight generation.    $ 50/mo
# 4968  Generation of promotional images without desig...          0
#
# [4969 rows x 9 columns]

# %% [markdown]
# Recategorize column Review

# %%
df['Review'].unique()
# Out:
# array([0, '1', '2', '8', '3', '4', '7', '10', '42', '14', '6', '5', '9',
#        '13', 'undefined', '11', '22', '15'], dtype=object)

# %%
# Función para categorizar los valores
def categorize(value):
    try:
        # Convertir el valor a entero si es posible
        value = int(value)
        if value == 0:
            return 'no review'
        elif 1 <= value <= 15:
            return 'few reviews'
        elif 16 <= value <= 45:
            return 'sufficient reviews'
    except (ValueError, TypeError):
        # Manejar el caso en que el valor no se pueda convertir a entero
        if value == 'undefined':
            return 'no review'
    # Valor por defecto
    return 'no review'

# Aplicar la función a la columna 'Review'
df['Review'] = df['Review'].apply(categorize)

# Mostrar el DataFrame resultante
print(df)
# Out:
#         Id    AI Tool Name                                          Tool Link  \
# 0        0          Farm3D  https://farm3d.github.io/?utm_source=futureped...
# 1        1   Mailbutler Ai  https://www.mailbutler.io/smart-assistant/?utm...
# 2        2       Maverick   https://www.trymaverick.com/?utm_source=future...
# 3        3            0Xai  https://0xai.quest?utm_source=futurepedia&utm_...
# 4        4           10Web  https://10web.io/?utm_source=futurepedia&utm_m...
# ...    ...             ...                                                ...
# 4964  4964         Zoom Iq  https://blog.zoom.us/zoom-iq-smart-companion/?...
# 4965  4965    Zoomscape Ai  https://zoomscape.ai/?utm_source=futurepedia&u...
# 4966  4966         Zust Qr  https://qr.zust.ai/?utm_source=futurepedia&utm...
# 4967  4967            Zuva  https://zuva.ai/widget/try-it/?utm_source=futu...
# 4968  4968            Zyng  https://www.zyngai.com/?utm_source=futurepedia...
#
#      Free/Paid       Review Major Category                    Useable For  \
# 0         Free    no review          other              [experiments, 3D]
# 1     Freemium  few reviews           text              [email assistant]
# 2         Paid    no review          audio    [e-commerce, audio editing]
# 3         Free    no review          image     [image generator, prompts]
# 4     Freemium    no review           code            [low-code, no-code]
# ...        ...          ...            ...                            ...
# 4964      Paid  few reviews           text  [summarizer, email assistant]
# 4965      Paid    no review       business                [presentations]
# 4966      Free    no review          image              [image generator]
# 4967      Paid  few reviews       business              [legal assistant]
# 4968      Free    no review          image  [e-commerce, image generator]
#
#                                             Description    Charges
# 0     Learning Articulated 3D Animals by Distilling ...          0
# 1     AI-powered Smart Assistant for Outlook, Gmail ...  $ 4.95/mo
# 2        Send customers personalized videos at scale.     $ 100/mo
# 3         Stable Diffusion Prompt And Images Generator           0
# 4     AI-powered WordPress platform for automated we...          0
# ...                                                 ...        ...
# 4964  Capture meaningful and actionable insights fro...          0
# 4965  ZoomScape AI is an AI-powered tool that enable...        $5
# 4966  Enables users to craft artistic QR codes by in...          0
# 4967          Contract analysis and insight generation.    $ 50/mo
# 4968  Generation of promotional images without desig...          0
#
# [4969 rows x 9 columns]

# %%
df['Review'].unique()
# Out:
# array(['no review', 'few reviews', 'sufficient reviews'], dtype=object)

# %% [markdown]
# Save clean original dataframe

# %%
df.to_csv('df_original_clean.csv', index=False)

# %% [markdown]
# Save clean original dataset without column 'Useable For'

# %%
df2 = df.drop('Useable For', axis = 1)

# %%
df2
# Out:
#         Id    AI Tool Name                                          Tool Link  \
# 0        0          Farm3D  https://farm3d.github.io/?utm_source=futureped...
# 1        1   Mailbutler Ai  https://www.mailbutler.io/smart-assistant/?utm...
# 2        2       Maverick   https://www.trymaverick.com/?utm_source=future...
# 3        3            0Xai  https://0xai.quest?utm_source=futurepedia&utm_...
# 4        4           10Web  https://10web.io/?utm_source=futurepedia&utm_m...
# ...    ...             ...                                                ...
# 4964  4964         Zoom Iq  https://blog.zoom.us/zoom-iq-smart-companion/?...
# 4965  4965    Zoomscape Ai  https://zoomscape.ai/?utm_source=futurepedia&u...
# 4966  4966         Zust Qr  https://qr.zust.ai/?utm_source=futurepedia&utm...
# 4967  4967            Zuva  https://zuva.ai/widget/try-it/?utm_source=futu...
# 4968  4968            Zyng  https://www.zyngai.com/?utm_source=futurepedia...
#
#      Free/Paid       Review Major Category  \
# 0         Free    no review          other
# 1     Freemium  few reviews           text
# 2         Paid    no review          audio
# 3         Free    no review          image
# 4     Freemium    no review           code
# ...        ...          ...            ...
# 4964      Paid  few reviews           text
# 4965      Paid    no review       business
# 4966      Free    no review          image
# 4967      Paid  few reviews       business
# 4968      Free    no review          image
#
#                                             Description    Charges
# 0     Learning Articulated 3D Animals by Distilling ...          0
# 1     AI-powered Smart Assistant for Outlook, Gmail ...  $ 4.95/mo
# 2        Send customers personalized videos at scale.     $ 100/mo
# 3         Stable Diffusion Prompt And Images Generator           0
# 4     AI-powered WordPress platform for automated we...          0
# ...                                                 ...        ...
# 4964  Capture meaningful and actionable insights fro...          0
# 4965  ZoomScape AI is an AI-powered tool that enable...        $5
# 4966  Enables users to craft artistic QR codes by in...          0
# 4967          Contract analysis and insight generation.    $ 50/mo
# 4968  Generation of promotional images without desig...          0
#
# [4969 rows x 8 columns]

# %%
df2.to_csv('df_original_clean_no_useablefor.csv', index=False)

# %% [markdown]
# Save clean original dataset with explode of column 'Useable For'

# %%
df
# Out:
#         Id    AI Tool Name                                          Tool Link  \
# 0        0          Farm3D  https://farm3d.github.io/?utm_source=futureped...
# 1        1   Mailbutler Ai  https://www.mailbutler.io/smart-assistant/?utm...
# 2        2       Maverick   https://www.trymaverick.com/?utm_source=future...
# 3        3            0Xai  https://0xai.quest?utm_source=futurepedia&utm_...
# 4        4           10Web  https://10web.io/?utm_source=futurepedia&utm_m...
# ...    ...             ...                                                ...
# 4964  4964         Zoom Iq  https://blog.zoom.us/zoom-iq-smart-companion/?...
# 4965  4965    Zoomscape Ai  https://zoomscape.ai/?utm_source=futurepedia&u...
# 4966  4966         Zust Qr  https://qr.zust.ai/?utm_source=futurepedia&utm...
# 4967  4967            Zuva  https://zuva.ai/widget/try-it/?utm_source=futu...
# 4968  4968            Zyng  https://www.zyngai.com/?utm_source=futurepedia...
#
#      Free/Paid       Review Major Category                    Useable For  \
# 0         Free    no review          other              [experiments, 3D]
# 1     Freemium  few reviews           text              [email assistant]
# 2         Paid    no review          audio    [e-commerce, audio editing]
# 3         Free    no review          image     [image generator, prompts]
# 4     Freemium    no review           code            [low-code, no-code]
# ...        ...          ...            ...                            ...
# 4964      Paid  few reviews           text  [summarizer, email assistant]
# 4965      Paid    no review       business                [presentations]
# 4966      Free    no review          image              [image generator]
# 4967      Paid  few reviews       business              [legal assistant]
# 4968      Free    no review          image  [e-commerce, image generator]
#
#                                             Description    Charges
# 0     Learning Articulated 3D Animals by Distilling ...          0
# 1     AI-powered Smart Assistant for Outlook, Gmail ...  $ 4.95/mo
# 2        Send customers personalized videos at scale.     $ 100/mo
# 3         Stable Diffusion Prompt And Images Generator           0
# 4     AI-powered WordPress platform for automated we...          0
# ...                                                 ...        ...
# 4964  Capture meaningful and actionable insights fro...          0
# 4965  ZoomScape AI is an AI-powered tool that enable...        $5
# 4966  Enables users to craft artistic QR codes by in...          0
# 4967          Contract analysis and insight generation.    $ 50/mo
# 4968  Generation of promotional images without desig...          0
#
# [4969 rows x 9 columns]

# %%
df['Useable For']
# Out:
# 0                   [experiments, 3D]
# 1                   [email assistant]
# 2         [e-commerce, audio editing]
# 3          [image generator, prompts]
# 4                 [low-code, no-code]
#                     ...
# 4964    [summarizer, email assistant]
# 4965                  [presentations]
# 4966                [image generator]
# 4967                [legal assistant]
# 4968    [e-commerce, image generator]
# Name: Useable For, Length: 4969, dtype: object

# %%
df3 = df.explode('Useable For', ignore_index = False)

# %%
df3.head()
# Out:
#    Id    AI Tool Name                                          Tool Link  \
# 0   0          Farm3D  https://farm3d.github.io/?utm_source=futureped...
# 0   0          Farm3D  https://farm3d.github.io/?utm_source=futureped...
# 1   1   Mailbutler Ai  https://www.mailbutler.io/smart-assistant/?utm...
# 2   2       Maverick   https://www.trymaverick.com/?utm_source=future...
# 2   2       Maverick   https://www.trymaverick.com/?utm_source=future...
#
#   Free/Paid       Review Major Category      Useable For  \
# 0      Free    no review          other      experiments
# 0      Free    no review          other               3D
# 1  Freemium  few reviews           text  email assistant
# 2      Paid    no review          audio       e-commerce
# 2      Paid    no review          audio    audio editing
#
#                                          Description    Charges
# 0  Learning Articulated 3D Animals by Distilling ...          0
# 0  Learning Articulated 3D Animals by Distilling ...          0
# 1  AI-powered Smart Assistant for Outlook, Gmail ...  $ 4.95/mo
# 2     Send customers personalized videos at scale.     $ 100/mo
# 2     Send customers personalized videos at scale.     $ 100/mo

# %%
df3['Useable For'].unique()
# Out:
# array(['experiments', '3D', 'email assistant', 'e-commerce',
#        'audio editing', 'image generator', 'prompts', 'low-code',
#        'no-code', 'fitness', 'video editing', 'social media assistant',
#        'finance', 'startup tools', 'life assistant', 'art', 'SEO',
#        'music', 'developer tools', 'summarizer', 'transcriber',
#        'healthcare', 'productivity', 'design assistant',
#        'human resources', 'fun tools', 'legal assistant',
#        'education assistant', 'memory', 'text to speech', 'copywriting',
#        'research', 'code assistant', 'customer support', 'image editing',
#        'resources', 'avatars', 'general writing', 'gaming', 'travel',
#        'dating', 'real estate', 'story teller', 'video generator',
#        'sales', 'SQL', 'gift ideas', 'fashion', 'presentations',
#        'search engine', 'spreadsheets', 'logo generator', 'religion',
#        'paraphraser', 'personalized videos'], dtype=object)

# %%
df3['Useable For'].nunique()
# Out:
# 55

# %%
df3.to_csv('df_original_clean_explode_useablefor.csv', index=False)

# %% [markdown]
# Create sampled dataframe with 'category', 'paid' and 'review'

# %%
df2['Major Category'].nunique()
# Out:
# 8

# %%
df2['Free/Paid'].nunique()
# Out:
# 3

# %%
df2['Review'].nunique()
# Out:
# 3

# %%
def sample_min_n(group_df, n_min):
  """
  Función para muestrear al menos n elementos de un grupo o el mínimo del grupo.

  Args:
    group_df: Dataframe de un solo grupo.
    n_min: Número mínimo de muestras.

  Returns:
    Dataframe muestreado.
  """
  n_samples = min(n_min, len(group_df))
  return group_df.sample(n=n_samples)

# %%
def sample_min_3(df, group_cols, n_min=3):
  """
  Función para muestrear al menos 3 elementos por grupo o el mínimo del grupo.

  Args:
    df: Dataframe a muestrear.
    group_cols: Lista de columnas por las que agrupar.
    n_min: Número mínimo de muestras por grupo (por defecto 3).

  Returns:
    Dataframe muestreado.
  """
  # Agrupar por columnas especificadas
  grouped_df = df.groupby(group_cols)

  # Aplicar función `sample_min_n` a cada grupo
  sampled_df = grouped_df.apply(sample_min_n, n_min=n_min)

  # Resetear índice
  sampled_df = sampled_df.reset_index(drop=True)

  return sampled_df

# %%
sampled_df = sample_min_3(df2,['Major Category', 'Free/Paid', 'Review'])

# %%
sampled_df.to_csv('df_sampled_category.csv', index=False)

# %% [markdown]
# Create sampled dataframe with 'major category', 'utility', 'paid' and 'review'

# %%
df3
# Out:
#         Id    AI Tool Name                                          Tool Link  \
# 0        0          Farm3D  https://farm3d.github.io/?utm_source=futureped...
# 0        0          Farm3D  https://farm3d.github.io/?utm_source=futureped...
# 1        1   Mailbutler Ai  https://www.mailbutler.io/smart-assistant/?utm...
# 2        2       Maverick   https://www.trymaverick.com/?utm_source=future...
# 2        2       Maverick   https://www.trymaverick.com/?utm_source=future...
# ...    ...             ...                                                ...
# 4965  4965    Zoomscape Ai  https://zoomscape.ai/?utm_source=futurepedia&u...
# 4966  4966         Zust Qr  https://qr.zust.ai/?utm_source=futurepedia&utm...
# 4967  4967            Zuva  https://zuva.ai/widget/try-it/?utm_source=futu...
# 4968  4968            Zyng  https://www.zyngai.com/?utm_source=futurepedia...
# 4968  4968            Zyng  https://www.zyngai.com/?utm_source=futurepedia...
#
#      Free/Paid       Review Major Category      Useable For  \
# 0         Free    no review          other      experiments
# 0         Free    no review          other               3D
# 1     Freemium  few reviews           text  email assistant
# 2         Paid    no review          audio       e-commerce
# 2         Paid    no review          audio    audio editing
# ...        ...          ...            ...              ...
# 4965      Paid    no review       business    presentations
# 4966      Free    no review          image  image generator
# 4967      Paid  few reviews       business  legal assistant
# 4968      Free    no review          image       e-commerce
# 4968      Free    no review          image  image generator
#
#                                             Description    Charges
# 0     Learning Articulated 3D Animals by Distilling ...          0
# 0     Learning Articulated 3D Animals by Distilling ...          0
# 1     AI-powered Smart Assistant for Outlook, Gmail ...  $ 4.95/mo
# 2        Send customers personalized videos at scale.     $ 100/mo
# 2        Send customers personalized videos at scale.     $ 100/mo
# ...                                                 ...        ...
# 4965  ZoomScape AI is an AI-powered tool that enable...        $5
# 4966  Enables users to craft artistic QR codes by in...          0
# 4967          Contract analysis and insight generation.    $ 50/mo
# 4968  Generation of promotional images without desig...          0
# 4968  Generation of promotional images without desig...          0
#
# [6489 rows x 9 columns]

# %%
sampled_df_2 = sample_min_3(df3,['Major Category', 'Useable For', 'Free/Paid', 'Review'])

# %%
sampled_df_2
# Out:
#         Id     AI Tool Name  \
# 0     3566          Recraft
# 1     1776   Get3D (Nvidia)
# 2     3611  Replicate Codex
# 3     3290            Ponzu
# 4     3851           Shap-E
# ...    ...              ...
# 1559  3447          Qlip.Ai
# 1560  4232       Taleblocks
# 1561  1837        Gliacloud
# 1562  4820  Wonder Dynamics
# 1563  4400     Tokkingheads
#
#                                               Tool Link Free/Paid  \
# 0     https://www.recraft.ai/?utm_source=futurepedia...      Free
# 1     https://nv-tlabs.github.io/GET3D/?utm_source=f...      Free
# 2     https://www.replicatecodex.com/?utm_source=fut...      Free
# 3     https://www.ponzu.gg/?utm_source=futurepedia&u...      Free
# 4     https://github.com/openai/shap-e?utm_source=fu...      Free
# ...                                                 ...       ...
# 1559  https://www.qlip.ai?utm_source=futurepedia&utm...      Paid
# 1560  https://www.taleblocks.com/?utm_source=futurep...      Paid
# 1561  https://www.gliacloud.com/en/?utm_source=futur...      Paid
# 1562  https://www.wonderdynamics.com/?utm_source=fut...      Paid
# 1563  https://www.rosebud.ai/tokkingheads?utm_source...      Paid
#
#            Review Major Category      Useable For  \
# 0     few reviews             3D               3D
# 1     few reviews             3D               3D
# 2     few reviews             3D               3D
# 3       no review             3D               3D
# 4       no review             3D               3D
# ...           ...            ...              ...
# 1559  few reviews          video  video generator
# 1560  few reviews          video  video generator
# 1561    no review          video  video generator
# 1562    no review          video  video generator
# 1563    no review          video  video generator
#
#                                             Description     Charges
# 0               Generate vector art, 3D images and more           0
# 1            Generative 3D Textured Shapes from Images.           0
# 2     A free tool to search, filter, sort, and disco...           0
# 3      AI-generated textures used to enhance 3D assets.           0
# 4     The GitHub repository openai/shap-e is an AI t...           0
# ...                                                 ...         ...
# 1559    Grow your social media with AI-generated clips.   $ 32.5/mo
# 1560  Taleblocks is an intuitive online video creati...  $ 19.99/mo
# 1561  GliaCloud is an automated video platform that ...           0
# 1562          At Wonder Dynamics, AI + storytelling = 🤩           0
# 1563  TokkingHeads is a powerful animation tool that...   $ 9.99/mo
#
# [1564 rows x 9 columns]

# %%
sampled_df_2['Major Category'].unique()
# Out:
# array(['3D', 'audio', 'business', 'code', 'image', 'other', 'text',
#        'video'], dtype=object)

# %%
sampled_df_2.to_csv('df_sampled_category_usability.csv', index=False)
